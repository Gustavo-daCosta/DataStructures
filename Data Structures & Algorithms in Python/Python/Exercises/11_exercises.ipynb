# %% [markdown]
# # Exercício 1
#
# Ler dois números inteiros, executar e mostrar o resultado das seguintes operações: adição, subtração, multiplicação e divisão

# %%
a = int(input("Digite um número inteiro:"))
b = int(input("Digite outro número inteiro"))

print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = int(input("Digite um número inteiro:"))
#       2 b = int(input("Digite outro número inteiro"))
#       4 print(a)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print(f"{a} + {b} = {a+b}")
print(f"{a} - {b} = {a-b}")
print(f"{a} * {b} = {a*b}")
print(f"{a} / {b} = {a/b}")
# Out:
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0

# %% [markdown]
# ---

# %% [markdown]
# ## Exercício 2
#
# Efetuar o cálculo da quantidade de litros de combustível gasto em uma viagem, utilizando um automóvel que faz 12 Km por litro. Para obter o cálculo, o usuário deve fornecer o tempo gasto na viagem e a velocidade média durante ela. Desta forma, será possível obter a distância percorrida com a fórmula DISTANCIA = TEMPO * VELOCIDADE. Tendo o valor da distância, basta calcular a quantidade de litros de combustível utilizada na viagem, com a fórmula: LITROS_USADOS = DISTANCIA / 12. O programa deve apresentar os valores da velocidade média, tempo gasto na viagem, a distância percorrida e a quantidade de litros utilizada na viagem

# %%
tempo_viagem = int(input("Tempo gasto na viagem em horas: "))
velocidade_media = float(input("Velocidade média na viagem em km/h: "))

distancia_percorrida = tempo_viagem * velocidade_media
litros_usados = distancia_percorrida / 12

print(f"Tempo de viagem: {tempo_viagem} horas")
print(f"Velocidade média: {velocidade_media:.1f} km/h")
print(f"Distância percorrida: {distancia_percorrida} km")
print(f"Quantidade de litros utilizados: {litros_usados} litros")
# Out:
# Tempo de viagem: 10 horas
# Velocidade média: 60.0 km/h
# Distância percorrida: 600.0 km
# Quantidade de litros utilizados: 50.0 litros
