# %% [markdown]
# # Exercício 1
#
# Ler 5 notas e informar a média

# %%
notas = list()
for i in range(0, 5):
    notas.append(float(input(f"Digite a nota {i}: ")))
media = sum(notas) / 5
print(f"Média: {media:.1f}")
# Out:
# Média: 7.4

# %% [markdown]
# ---

# %% [markdown]
# # Exercício 2
#
# Imprimir a tabuada do número 3 (3x1 = 1 - 3 x 10 = 30)

# %%
for i in range(1, 11):
    print(f"3 * {i} = {3 * i}")
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
